# %% [markdown]
# # Cell 1: download your repo

# %%
# !wget -qO repo.zip https://github.com/AlinBolcas/Gemma4_FineTune_Creativity/archive/refs/heads/main.zip
# !unzip -q repo.zip -d /kaggle/working
# !rm -f repo.zip
# !mv /kaggle/working/Gemma4_FineTune_Creativity-main /kaggle/working/Gemma4_FineTune_Creativity

# %% [markdown]
# # Cell 2: move into repo

# %%
import os, sys
from pathlib import Path

ROOT = Path("/kaggle/working/Gemma4_FineTune_Creativity")
os.chdir(ROOT)
sys.path.insert(0, str(ROOT))

print(ROOT)

# %% [markdown]
# # Cell 3: install training deps

# %%
# !pip install -q -U unsloth datasets trl peft accelerate bitsandbytes huggingface_hub sentencepiece
# !pip install -q "protobuf>=5.26,<6"

# %%
modules = ["unsloth", "torch", "transformers", "datasets", "trl", "peft"]

for name in modules:
    try:
        __import__(name)
        print(f"OK: {name}")
    except Exception as e:
        print(f"FAIL: {name} -> {e}")

# %% [markdown]
# # Cell 4: load Hugging Face token

# %%
from kaggle_secrets import UserSecretsClient
from huggingface_hub import login
import os

hf_token = UserSecretsClient().get_secret("HF_TOKEN")
login(token=hf_token)
os.environ["HUGGINGFACE_ACCESS_TOKEN"] = hf_token

print("HF token loaded")

# %% [markdown]
# # Cell 5: verify GPU

# %%
import torch

print("CUDA:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU:", torch.cuda.get_device_name(0))

# %% [markdown]
# # Cell 6: build a fresh Kaggle config
# This makes a new config using Kaggle paths, not your Mac paths.

# %%
from src.III_fineTune.sft_train import (
    discover_dataset_bundles,
    build_run_config,
    save_run_config,
    run_preflight,
)

bundles = discover_dataset_bundles()
print(bundles)

bundle = bundles[0]

config = build_run_config(
    bundle=bundle,
    model_alias="e2b",
    backend="unsloth",
    run_name="kaggle_smoke_e2b",
)

config["runtime"]["target"] = "kaggle"
config["training"]["output_dir"] = "data/output/models/kaggle_smoke_e2b"
config["training"]["num_train_epochs"] = 1
config["training"]["max_steps"] = 30
config["training"]["per_device_train_batch_size"] = 1
config["training"]["gradient_accumulation_steps"] = 4
config["training"]["max_seq_length"] = 4096

config_path = save_run_config(config)
print(config_path)

summary = run_preflight(config)
summary

# %% [markdown]
# # Cell 7: train

# %%
from src.III_fineTune.sft_train import train_from_config
train_from_config(config)

# %% [markdown]
# # Cell 8: find the newest adapter + training run

# %%
from pathlib import Path

models_dir = ROOT / "data" / "output" / "models"
runs_dir = ROOT / "data" / "output" / "training_runs"

adapter_dirs = sorted(
    [p for p in models_dir.glob("*") if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)
run_dirs = sorted(
    [p for p in runs_dir.glob("*") if p.is_dir()],
    key=lambda p: p.stat().st_mtime,
    reverse=True,
)

print("Adapters:")
for p in adapter_dirs[:10]:
    print(" -", p.name)

print("\nTraining runs:")
for p in run_dirs[:10]:
    print(" -", p.name)

adapter_path = adapter_dirs[0]
run_path = run_dirs[0]

print("\nUsing adapter:", adapter_path)
print("Using run dir:", run_path)

# %% [markdown]
# # Cell 10: load vanilla + fine-tuned models

# %%
from src.IV_inference.gemma4_integration import load_gemma4, load_finetuned_gemma4

vanilla = load_gemma4("e2b", thinking=False, use_memory=False)
tuned = load_finetuned_gemma4(
    adapter_path=str(adapter_path),
    base_model="e2b",
    thinking=False,
    use_memory=False,
)

print("Loaded vanilla and fine-tuned models")

# %% [markdown]
# # Cell 11: quick direct comparison

# %%
prompt = "What project ideas would you generate for the Gemma 4 Good Hackathon that would genuinely impress judges?"

print("=== VANILLA ===")
print(vanilla("You are a helpful assistant.", prompt))

print("\n=== FINE-TUNED ===")
print(tuned("You are a helpful assistant.", prompt))

# %% [markdown]
# # Cell 12: batch evaluation on held-out prompts

# %%
from src.IV_inference.evaluate import evaluate, export_eval, load_eval_prompts

prompts = load_eval_prompts()
results = evaluate(
    generate_fn_vanilla=vanilla,
    generate_fn_tuned=tuned,
    prompts=prompts,
    verbose=True,
)

eval_out = ROOT / "data/output/eval_kaggle_posttrain.json"
export_eval(results, eval_out)

print("Saved:", eval_out)

# %% [markdown]
# # Cell 13: save readable markdown report

# %%
import json

md_path = ROOT / "data/output/eval_kaggle_posttrain.md"

with open(eval_out, encoding="utf-8") as f:
    eval_rows = json.load(f)

lines = ["# Post-Training Evaluation", ""]
for i, row in enumerate(eval_rows, 1):
    lines.append(f"## Prompt {i}")
    lines.append("")
    lines.append(f"**Prompt:** {row['prompt']}")
    lines.append("")
    lines.append("### Tier 1 - Vanilla")
    lines.append("")
    lines.append(row["tier1_vanilla"])
    lines.append("")
    lines.append("### Tier 2 - Scaffolded Vanilla")
    lines.append("")
    lines.append(row["tier2_scaffolded"])
    lines.append("")
    lines.append("### Tier 3 - Fine-Tuned")
    lines.append("")
    lines.append(row["tier3_tuned"])
    lines.append("")
    lines.append("---")
    lines.append("")

md_path.write_text("\n".join(lines), encoding="utf-8")
print("Saved:", md_path)

# %% [markdown]
# # Cell 14: load training logs and metrics

# %%
import json
import pandas as pd

log_history_path = run_path / "log_history.json"
train_metrics_path = run_path / "train_metrics.json"
eval_metrics_path = run_path / "eval_metrics.json"

with open(log_history_path, encoding="utf-8") as f:
    log_history = json.load(f)

df = pd.DataFrame(log_history)
display(df.tail())

train_metrics = {}
eval_metrics = {}

if train_metrics_path.exists():
    with open(train_metrics_path, encoding="utf-8") as f:
        train_metrics = json.load(f)

if eval_metrics_path.exists():
    with open(eval_metrics_path, encoding="utf-8") as f:
        eval_metrics = json.load(f)

print("TRAIN METRICS")
print(train_metrics)
print("\nEVAL METRICS")
print(eval_metrics)

# %% [markdown]
# # Cell 15: plot loss / learning-rate / gradient norm

# %%
import matplotlib.pyplot as plt

if "loss" in df.columns:
    train_df = df[df["loss"].notna()]
    plt.figure(figsize=(10, 5))
    plt.plot(train_df["step"], train_df["loss"], marker="o", label="train loss")

    if "eval_loss" in df.columns:
        eval_df = df[df["eval_loss"].notna()]
        if len(eval_df) > 0:
            plt.plot(eval_df["step"], eval_df["eval_loss"], marker="s", label="eval loss")

    plt.title("Training / Eval Loss")
    plt.xlabel("Step")
    plt.ylabel("Loss")
    plt.grid(True)
    plt.legend()
    plt.show()

if "learning_rate" in df.columns:
    lr_df = df[df["learning_rate"].notna()]
    if len(lr_df) > 0:
        plt.figure(figsize=(10, 4))
        plt.plot(lr_df["step"], lr_df["learning_rate"], marker=".")
        plt.title("Learning Rate")
        plt.xlabel("Step")
        plt.ylabel("LR")
        plt.grid(True)
        plt.show()

if "grad_norm" in df.columns:
    gn_df = df[df["grad_norm"].notna()]
    if len(gn_df) > 0:
        plt.figure(figsize=(10, 4))
        plt.plot(gn_df["step"], gn_df["grad_norm"], marker=".")
        plt.title("Gradient Norm")
        plt.xlabel("Step")
        plt.ylabel("Grad Norm")
        plt.grid(True)
        plt.show()

# %% [markdown]
# # Cell 16: custom prompt batch test

# %%
custom_prompts = [
    "Name a multilingual education platform for refugee communities.",
    "Reframe burnout as a systems problem rather than an individual weakness.",
    "Find a deep structural analogy between coral reefs and open-source communities.",
    "Design a creative mentorship system for students without internet access.",
    "Invent a new field of study that combines neuroscience, design, and indigenous knowledge.",
]

rows = []
for prompt in custom_prompts:
    rows.append({
        "prompt": prompt,
        "vanilla": vanilla("You are a helpful assistant.", prompt),
        "tuned": tuned("You are a helpful assistant.", prompt),
    })

for row in rows:
    print("=" * 80)
    print("PROMPT:", row["prompt"])
    print("\nVANILLA:\n", row["vanilla"])
    print("\nTUNED:\n", row["tuned"])
    print()
